# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tips = pd.read_csv(r'./result/ts115-violinplot-kaggle-0630.csv')

style_all = {'axes.facecolor': 'white',
 'axes.edgecolor': 'black',
 'axes.grid': False,
 'axes.axisbelow': 'line',
 'axes.labelcolor': 'black',
 'figure.facecolor': 'white',
 'grid.color': '#b0b0b0',
 'grid.linestyle': '-',
 'text.color': 'black',
 'xtick.color': 'black',
 'ytick.color': 'black',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'patch.edgecolor': 'black',
 'patch.force_edgecolor': False,
 'image.cmap': 'viridis',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['DejaVu Sans',
  'Bitstream Vera Sans',
  'Computer Modern Sans Serif',
  'Lucida Grande',
  'Verdana',
  'Geneva',
  'Lucid',
  'Arial',
  'Helvetica',
  'Avant Garde',
  'sans-serif'],
 'xtick.bottom': True,
 'xtick.top': False,
 'ytick.left': True,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True}
sns.set_theme(style=style_all,font_scale=1.3)
sns.set_style("whitegrid")
ax = sns.violinplot(x = "ss8_origi_label", 
               y = "psi_loss", 
               data = tips, 
               palette="Set2",
              )

# ax.set_xticklabels(['Helices', 'Strands', 'Coils'])
ax.set_xticklabels(['G', 'H', 'I', 'B', 'E', 'S', 'T', 'C'])
# ax.set_yticklabels([0, 50, 100, 150, 200])
# ax.set_xticklabels(['3–10 helix', 'α helix', 'π helix', 'β bridge,', 'extended strand', 'bend', ' h-bonded turn', 'coil'])
ax.set_xlabel('SS8')
ax.set_ylabel('Prediction Error')
plt.title("Psi")
# Out:
# Text(0.5, 1.0, 'Psi')

# %%
tips = pd.read_csv(r'./result/ts115-violinplot-kaggle-0630.csv')

# %%
tips['psi_loss'].min()
# Out:
# 0.00035095215

# %%
tips['psi_loss'].max()
# Out:
# 179.96088
