# %%
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd

# %%
tips = pd.read_csv("./result/ts115/ts115-ss3-result.csv")

# %%
tips.head()
# Out:
#    Unnamed: 0  % of Accuracy/Recall/F1-score Evaluation Metrics      SS3
# 0           0                           0.91          Precision  Helices
# 1           1                           0.90             Recall  Helices
# 2           2                           0.90           F1-score  Helices
# 3           3                           0.85          Precision  Strands
# 4           4                           0.83             Recall  Strands

# %%
# ax = sns.scatterplot(x='SS3', y='% of Accuracy/Recall/F1-score', hue='Evaluation Metrics', data=tips)
import matplotlib.pyplot as plt
style_all = {'axes.facecolor': 'white',
 'axes.edgecolor': 'black',
 'axes.grid': False,
 'axes.axisbelow': 'line',
 'axes.labelcolor': 'black',
 'figure.facecolor': 'white',
 'grid.color': '#b0b0b0',
 'grid.linestyle': '-',
 'text.color': 'black',
 'xtick.color': 'black',
 'ytick.color': 'black',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'patch.edgecolor': 'black',
 'patch.force_edgecolor': False,
 'image.cmap': 'viridis',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['DejaVu Sans',
  'Bitstream Vera Sans',
  'Computer Modern Sans Serif',
  'Lucida Grande',
  'Verdana',
  'Geneva',
  'Lucid',
  'Arial',
  'Helvetica',
  'Avant Garde',
  'sans-serif'],
 'xtick.bottom': True,
 'xtick.top': False,
 'ytick.left': True,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True}
sns.set_theme(style=style_all,font_scale=1.3)
ax = sns.barplot(x="SS3",y="% of Accuracy/Recall/F1-score",hue="Evaluation Metrics",data=tips)
# plt.legend(labels=["Precision","Recall","F11-score"], loc = 2, bbox_to_anchor = (1,1))
# sns.barplot(x=" ",y=" ",hue="Evaluation Metrics",data=tips)
# font1 = {'family' : 'Times New Roman',
# 'weight' : 'normal',
# 'size' : 14,
# }
# plt.xlabel("SS3", fontsize=14,fontweight='medium')
# plt.ylabel("% of Accuracy/Recall/F1-score", fontsize=14,fontweight='medium')
# plt.show()
ax.legend(loc=9)

# %%
tips_ss8 = pd.read_csv("./result/ts115/ts115-ss8-result.csv")

# %%
tips_ss8.head()
# Out:
#    Unnamed: 0  % of Accuracy/Recall/F1-score Evaluation Metrics  number SS8
# 0           0                           0.46          Precision       0   G
# 1           1                           0.32             Recall       0   G
# 2           2                           0.38           F1-score       0   G
# 3           3                           0.88          Precision       1   H
# 4           4                           0.93             Recall       1   H

# %%
# ax = sns.scatterplot(x='SS3', y='% of Accuracy/Recall/F1-score', hue='Evaluation Metrics', data=tips)
import matplotlib.pyplot as plt
style_all = {'axes.facecolor': 'white',
 'axes.edgecolor': 'black',
 'axes.grid': False,
 'axes.axisbelow': 'line',
 'axes.labelcolor': 'black',
 'figure.facecolor': 'white',
 'grid.color': '#b0b0b0',
 'grid.linestyle': '-',
 'text.color': 'black',
 'xtick.color': 'black',
 'ytick.color': 'black',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'patch.edgecolor': 'black',
 'patch.force_edgecolor': False,
 'image.cmap': 'viridis',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['DejaVu Sans',
  'Bitstream Vera Sans',
  'Computer Modern Sans Serif',
  'Lucida Grande',
  'Verdana',
  'Geneva',
  'Lucid',
  'Arial',
  'Helvetica',
  'Avant Garde',
  'sans-serif'],
 'xtick.bottom': True,
 'xtick.top': False,
 'ytick.left': True,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True}
sns.set_theme(style=style_all,font_scale=1.3)
ax = sns.barplot(x="SS8",y="% of Accuracy/Recall/F1-score",hue="Evaluation Metrics",data=tips_ss8)
ax.legend(loc=9)

# %%
sns.barplot(x="SS8",y="% of Accuracy/Recall/F1-score",hue="Evaluation Metrics",data=tips_ss8)
plt.xlabel("SS8", fontsize=14,fontweight='medium')
plt.ylabel("% of Accuracy/Recall/F1-score", fontsize=14,fontweight='medium')
plt.show()

# %%
train = {0: 0.03615788741606486, 1: 0.31851486400898127, 2: 0.00503171945890785, 3: 0.009549823610729114, 4: 0.20447426004059407, 5: 0.07609519123729973, 6: 0.10237329884623365, 7: 0.24780295538118943}
ts115 = {0: 0.03477646108268247, 1: 0.3512658227848101, 2: 0.005857796929706437, 3: 0.009931322380824132, 4: 0.1711890654457312, 5: 0.07440075410719095, 6: 0.09678831133854027, 7: 0.2557904659305144}
cb513 = {0: 0.03600027708506511, 1: 0.29914103629814354, 2: 0.005548628428927681, 3: 0.012697423108894431, 4: 0.20876281518426157, 5: 0.09393876420060959, 6: 0.11431144361318925, 7: 0.22959961208090884}
casp12 = {0: 0.029630650496141126, 1: 0.27411797133406834, 2: 0.0050992282249173095, 3: 0.008544652701212789, 4: 0.19514884233737598, 5: 0.09206174200661521, 6: 0.08723814773980154, 7: 0.3081587651598677}
casp14_32 = {0: 0.030271277215042497, 1: 0.35813249505181044, 2: 0.0029106997322156246, 3: 0.010478519035976248, 4: 0.2162067761089766, 5: 0.07835603679124462, 6: 0.10909302596344161, 7: 0.19455117010129236}

# %%
train_list = list(train.values())
ts115_list = list(ts115.values())
cb513_list = list(cb513.values())
casp12_list = list(casp12.values())
casp14_32_list = list(casp14_32.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /root/luohui/draw_barplot.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> train_list = list(train.values())
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> ts115_list = list(ts115.values())
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> cb513_list = list(cb513.values())
#
# NameError: name 'train' is not defined

# %%
aa = {
    "train_list":train_list,
    "ts115_list":ts115_list,
    "cb513_list":cb513_list,
    "casp12_list":casp12_list,
    "casp14_32_list":casp14_32_list
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /root/luohui/draw_barplot.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> aa = {
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     "train_list":train_list,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     "ts115_list":ts115_list,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     "cb513_list":cb513_list,
# ...

# %%
from pandas.core.frame import DataFrame
data_d=DataFrame(aa)
dd = data_d.to_csv('./result/train_test_labels_count.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /root/luohui/draw_barplot.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from pandas.core.frame import DataFrame
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> data_d=DataFrame(aa)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/root/luohui/draw_barplot.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> dd = data_d.to_csv('./result/train_test_labels_count.csv')
#
# NameError: name 'aa' is not defined

# %%
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd

# %%
train_test = pd.read_csv("./result/train_test_labels_count_all.csv")

# %%
train_test.head()
# Out:
#    Unnamed: 0  Frequency datasets SS8  number
# 0           0   0.036158    Train   G       0
# 1           1   0.318515    Train   H       1
# 2           2   0.005032    Train   I       2
# 3           3   0.009550    Train   B       3
# 4           4   0.204474    Train   E       4

# %%
# ax = sns.scatterplot(x='SS3', y='% of Accuracy/Recall/F1-score', hue='Evaluation Metrics', data=tips)
import matplotlib.pyplot as plt
style_all = {'axes.facecolor': 'white',
 'axes.edgecolor': 'black',
 'axes.grid': False,
 'axes.axisbelow': 'line',
 'axes.labelcolor': 'black',
 'figure.facecolor': 'white',
 'grid.color': '#b0b0b0',
 'grid.linestyle': '-',
 'text.color': 'black',
 'xtick.color': 'black',
 'ytick.color': 'black',
 'xtick.direction': 'out',
 'ytick.direction': 'out',
 'patch.edgecolor': 'black',
 'patch.force_edgecolor': False,
 'image.cmap': 'viridis',
 'font.family': ['sans-serif'],
 'font.sans-serif': ['DejaVu Sans',
  'Bitstream Vera Sans',
  'Computer Modern Sans Serif',
  'Lucida Grande',
  'Verdana',
  'Geneva',
  'Lucid',
  'Arial',
  'Helvetica',
  'Avant Garde',
  'sans-serif'],
 'xtick.bottom': True,
 'xtick.top': False,
 'ytick.left': True,
 'ytick.right': False,
 'axes.spines.left': True,
 'axes.spines.bottom': True,
 'axes.spines.right': True,
 'axes.spines.top': True}
sns.set_theme(style=style_all,font_scale=1.3)
sns.barplot(x="SS8",y="Frequency",hue="datasets",data=train_test,saturation=.75)
# Out:
# <Axes: xlabel='SS8', ylabel='Frequency'>

# %%
ax = sns.barplot(x="SS8",y="Frequency",hue="datasets",data=train_test)
plt.xlabel("SS8", fontsize=14,fontweight='medium')
plt.ylabel("Frequency", fontsize=14,fontweight='medium')
ax.legend(loc=9)
plt.show()
